# %%
from main import main, Args

# Function to run the main script with specified arguments.

# Define your own paths:
PATH_DATA = ""
PATH_MASKS = ""
PATH_SAVE = ""

# Define the arguments for the main function (see main.py for details)
args = Args(
    pathData=PATH_DATA,
    pathMasks=PATH_MASKS,
    pathSave=PATH_SAVE,
    batchSize=4,
    epochs=50
)

main(args)

# %%
from inference import inference
import matplotlib.pyplot as plt

# Runs inference on a single image using our trained segmentation model
# Model_name is either "efficientnet-b5" or "efficientnet-b7"
# Use_lgbm is True if you want to use LightGBM for post-processing,

# Define your own paths:
PATH_IMAGE = "" # path to single image
PATH_MODELS = "" # path to models folder (CNN and LGBM)

prediction = inference(PATH_IMAGE, PATH_MODELS, model_name="efficientnet-b5", use_lgbm=True, resize_target=(1024, 1024))
plt.imshow(prediction * 255, cmap='gray')
plt.show()

# %%
from inference import full_inference

# Runs inference on a single image using our trained segmentation model
# Model_name is either "efficientnet-b5" or "efficientnet-b7"
# The function returns predictions for 512, 1024, and 2048 sizes, as well as the LightGBM prediction.
# Show_plots is True if you want to visualize the predictions.

PATH_IMAGE = "" # path to single image
PATH_MODELS = "" # path to models folder (CNN and LGBM)

prediction_512, prediction_1024, prediction_2048, prediction_lgbm = full_inference(PATH_IMAGE, PATH_MODELS, model_name='efficientnet-b5', show_plots=True)
